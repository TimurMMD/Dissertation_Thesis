# %% [markdown]
# <a href="https://colab.research.google.com/github/TimurMMD/Dissertation_Thesis/blob/main/List_stock_indicators.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import pandas as pd
import zipfile
import io
import time

# %%
pip install eodhd
# Out:
# Collecting eodhd
#   Downloading eodhd-1.0.31-py3-none-any.whl.metadata (2.9 kB)
# Collecting websockets>=11.0.3 (from eodhd)
#   Downloading websockets-13.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.8 kB)
# Requirement already satisfied: websocket-client>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from eodhd) (1.8.0)
# Requirement already satisfied: requests>=2.31.0 in /usr/local/lib/python3.10/dist-packages (from eodhd) (2.32.3)
# Requirement already satisfied: rich>=13.5.2 in /usr/local/lib/python3.10/dist-packages (from eodhd) (13.9.2)
# Requirement already satisfied: pandas>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from eodhd) (2.2.2)
# Requirement already satisfied: numpy>=1.25.2 in /usr/local/lib/python3.10/dist-packages (from eodhd) (1.26.4)
# Collecting matplotlib>=3.7.2 (from eodhd)
#   Downloading matplotlib-3.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.7.2->eodhd) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.7.2->eodhd) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.7.2->eodhd) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.7.2->eodhd) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.7.2->eodhd) (24.1)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.7.2->eodhd) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.7.2->eodhd) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.7.2->eodhd) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=2.1.0->eodhd) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=2.1.0->eodhd) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31.0->eodhd) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31.0->eodhd) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31.0->eodhd) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31.0->eodhd) (2024.8.30)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=13.5.2->eodhd) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=13.5.2->eodhd) (2.18.0)
# Requirement already satisfied: typing-extensions<5.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from rich>=13.5.2->eodhd) (4.12.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=13.5.2->eodhd) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.7.2->eodhd) (1.16.0)
# Downloading eodhd-1.0.31-py3-none-any.whl (30 kB)
# Downloading matplotlib-3.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 22.1 MB/s eta 0:00:00
# Downloading websockets-13.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (164 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.1/164.1 kB 7.8 MB/s eta 0:00:00
# Installing collected packages: websockets, matplotlib, eodhd
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.7.1
#     Uninstalling matplotlib-3.7.1:
#       Successfully uninstalled matplotlib-3.7.1
# Successfully installed eodhd-1.0.31 matplotlib-3.9.2 websockets-13.1

# %%
symbols = pd.read_csv('sp500_symbols.csv')

# %%
symbol_list = symbols['Symbol'].tolist()

# %%
symbol_list
# Out:
# ['MMM',
#  'AOS',
#  'ABT',
#  'ABBV',
#  'ACN',
#  'ADBE',
#  'AMD',
#  'AES',
#  'AFL',
#  'A',
#  'APD',
#  'AKAM',
#  'ALB',
#  'ARE',
#  'ALGN',
#  'ALLE',
#  'LNT',
#  'ALL',
#  'GOOGL',
#  'GOOG',
#  'MO',
#  'AMZN',
#  'AEE',
#  'AEP',
#  'AXP',
#  'AIG',
#  'AMT',
#  'AWK',
#  'AMP',
#  'AME',
#  'AMGN',
#  'APH',
#  'ADI',
#  'ANSS',
#  'AON',
#  'APA',
#  'AAPL',
#  'AMAT',
#  'APTV',
#  'ADM',
#  'ANET',
#  'AJG',
#  'AIZ',
#  'T',
#  'ADSK',
#  'ADP',
#  'AZO',
#  'AVB',
#  'AVY',
#  'BKR',
#  'BALL',
#  'BAC',
#  'BAX',
#  'BDX',
#  'BRK.B',
#  'BBY',
#  'BIIB',
#  'BLK',
#  'BK',
#  'BA',
#  'BKNG',
#  'BWA',
#  'BSX',
#  'BMY',
#  'AVGO',
#  'BR',
#  'BF.B',
#  'BXP',
#  'CHRW',
#  'CDNS',
#  'CPB',
#  'COF',
#  'CAH',
#  'KMX',
#  'CCL',
#  'CAT',
#  'CBOE',
#  'CBRE',
#  'CE',
#  'COR',
#  'CNC',
#  'CNP',
#  'CF',
#  'SCHW',
#  'CHTR',
#  'CVX',
#  'CMG',
#  'CB',
#  'CHD',
#  'CI',
#  'CINF',
#  'CTAS',
#  'CSCO',
#  'C',
#  'CFG',
#  'CLX',
#  'CME',
#  'CMS',
#  'KO',
#  'CTSH',
#  'CL',
#  'CMCSA',
#  'CAG',
#  'COP',
#  'ED',
#  'STZ',
#  'COO',
#  'CPRT',
#  'GLW',
#  'CPAY',
#  'COST',
#  'CTRA',
#  'CCI',
#  'CSX',
#  'CMI',
#  'CVS',
#  'DHR',
#  'DRI',
#  'DVA',
#  'DE',
#  'DAL',
#  'DVN',
#  'FANG',
#  'DLR',
#  'DFS',
#  'DG',
#  'DLTR',
#  'D',
#  'DOV',
#  'DHI',
#  'DTE',
#  'DUK',
#  'EMN',
#  'ETN',
#  'EBAY',
#  'ECL',
#  'EIX',
#  'EW',
#  'EA',
#  'ELV',
#  'EMR',
#  'ETR',
#  'EOG',
#  'EFX',
#  'EQIX',
#  'EQR',
#  'ESS',
#  'EL',
#  'EG',
#  'EVRG',
#  'ES',
#  'EXC',
#  'EXPE',
#  'EXPD',
#  'EXR',
#  'XOM',
#  'FFIV',
#  'FAST',
#  'FRT',
#  'FDX',
#  'FIS',
#  'FITB',
#  'FE',
#  'FI',
#  'FMC',
#  'F',
#  'FTNT',
#  'FTV',
#  'BEN',
#  'FCX',
#  'GRMN',
#  'IT',
#  'GE',
#  'GEN',
#  'GD',
#  'GIS',
#  'GM',
#  'GPC',
#  'GILD',
#  'GPN',
#  'GL',
#  'GS',
#  'HAL',
#  'HIG',
#  'HAS',
#  'HCA',
#  'DOC',
#  'HSIC',
#  'HSY',
#  'HES',
#  'HPE',
#  'HLT',
#  'HOLX',
#  'HD',
#  'HON',
#  'HRL',
#  'HST',
#  'HWM',
#  'HPQ',
#  'HUM',
#  'HBAN',
#  'HII',
#  'IBM',
#  'IDXX',
#  'ITW',
#  'INCY',
#  'INTC',
#  'ICE',
#  'IFF',
#  'IP',
#  'IPG',
#  'INTU',
#  'ISRG',
#  'IVZ',
#  'IQV',
#  'IRM',
#  'JBHT',
#  'JKHY',
#  'J',
#  'JNJ',
#  'JCI',
#  'JPM',
#  'JNPR',
#  'K',
#  'KEY',
#  'KEYS',
#  'KMB',
#  'KIM',
#  'KMI',
#  'KLAC',
#  'KHC',
#  'KR',
#  'LHX',
#  'LH',
#  'LRCX',
#  'LW',
#  'LEN',
#  'LLY',
#  'LIN',
#  'LKQ',
#  'LMT',
#  'L',
#  'LOW',
#  'LYB',
#  'MTB',
#  'MRO',
#  'MPC',
#  'MAR',
#  'MMC',
#  'MLM',
#  'MAS',
#  'MA',
#  'MKC',
#  'MCD',
#  'MCK',
#  'MDT',
#  'MRK',
#  'META',
#  'MET',
#  'MTD',
#  'MGM',
#  'MCHP',
#  'MU',
#  'MSFT',
#  'MAA',
#  'MHK',
#  'TAP',
#  'MDLZ',
#  'MNST',
#  'MCO',
#  'MS',
#  'MOS',
#  'MSI',
#  'MSCI',
#  'NDAQ',
#  'NTAP',
#  'NFLX',
#  'NEM',
#  'NWSA',
#  'NWS',
#  'NEE',
#  'NKE',
#  'NI',
#  'NSC',
#  'NTRS',
#  'NOC',
#  'NCLH',
#  'NRG',
#  'NUE',
#  'NVDA',
#  'ORLY',
#  'OXY',
#  'OMC',
#  'OKE',
#  'ORCL',
#  'PCAR',
#  'PKG',
#  'PARA',
#  'PH',
#  'PAYX',
#  'PYPL',
#  'PNR',
#  'PEP',
#  'PFE',
#  'PM',
#  'PSX',
#  'PNW',
#  'PNC',
#  'PPG',
#  'PPL',
#  'PFG',
#  'PG',
#  'PGR',
#  'PLD',
#  'PRU',
#  'PEG',
#  'PSA',
#  'PHM',
#  'QRVO',
#  'PWR',
#  'QCOM',
#  'DGX',
#  'RL',
#  'RJF',
#  'RTX',
#  'O',
#  'REG',
#  'REGN',
#  'RF',
#  'RSG',
#  'RMD',
#  'RVTY',
#  'ROK',
#  'ROL',
#  'ROP',
#  'ROST',
#  'RCL',
#  'SPGI',
#  'CRM',
#  'SBAC',
#  'SLB',
#  'STX',
#  'SRE',
#  'SHW',
#  'SPG',
#  'SWKS',
#  'SJM',
#  'SNA',
#  'SO',
#  'LUV',
#  'SWK',
#  'SBUX',
#  'STT',
#  'SYK',
#  'SYF',
#  'SNPS',
#  'SYY',
#  'TTWO',
#  'TPR',
#  'TGT',
#  'TEL',
#  'TXN',
#  'TXT',
#  'TMO',
#  'TJX',
#  'TSCO',
#  'TT',
#  'TDG',
#  'TRV',
#  'TFC',
#  'TSN',
#  'USB',
#  'UDR',
#  'ULTA',
#  'UNP',
#  'UAL',
#  'UPS',
#  'URI',
#  'UNH',
#  'UHS',
#  'VLO',
#  'VTR',
#  'VRSN',
#  'VRSK',
#  'VZ',
#  'VRTX',
#  'VTRS',
#  'V',
#  'VMC',
#  'GWW',
#  'WBA',
#  'WMT',
#  'DIS',
#  'WM',
#  'WAT',
#  'WEC',
#  'WFC',
#  'WELL',
#  'WDC',
#  'WY',
#  'WMB',
#  'WTW',
#  'WYNN',
#  'XEL',
#  'XYL',
#  'YUM',
#  'ZBH',
#  'ZTS']

# %%
# Function to get data for a specific ticker and data type
def get_financial_data(ticker, data_type, api_token):
    url = f'https://eodhd.com/api/fundamentals/{ticker}.US?filter=Financials::{data_type}::quarterly&api_token=6710b76ee76761.47900881&fmt=json'
    data = requests.get(url).json()
    return pd.DataFrame(data).T



# Function to get earnings history
def get_earnings_data(ticker, api_token):
    url = f'https://eodhd.com/api/fundamentals/{ticker}.US?filter=Earnings::History&api_token=6710b76ee76761.47900881&fmt=json'
    data = requests.get(url).json()
    return pd.DataFrame(data).T



# Function to get stock prices for the ticker
def get_stock_prices(ticker, api_token, start_date='2019-09-24', end_date='2024-07-25'):
    url = f'https://eodhd.com/api/eod/{ticker}.US?from={start_date}&to={end_date}&period=d&api_token=6710b76ee76761.47900881&fmt=json'
    data = requests.get(url).json()
    price_df = pd.DataFrame(data).set_index('date')
    return price_df[['close']]

# %%
# Function to process and calculate financial indicators for a given ticker
def process_financial_data(ticker, api_token):

    # Get all relevant financial data
    df_bs = get_financial_data(ticker, "Balance_Sheet", api_token)
    df_is = get_financial_data(ticker, "Income_Statement", api_token)
    df_cf = get_financial_data(ticker, "Cash_Flow", api_token)
    df_earn = get_earnings_data(ticker, api_token)

    # Select relevant columns and set index
    df_bs = df_bs[['date', 'totalCurrentAssets', 'totalCurrentLiabilities', 'inventory', 'totalLiab', 'totalStockholderEquity', 'totalAssets', 'netDebt']].set_index('date')
    df_is = df_is[['date', 'ebit', 'interestExpense', 'totalRevenue', 'costOfRevenue', 'operatingIncome', 'netIncome']].set_index('date')
    df_cf = df_cf[['date', 'freeCashFlow', 'totalCashFromOperatingActivities']].set_index('date')
    df_earn = df_earn[['date', 'epsActual']].set_index('date')
    # Filter this dataset for current dates
    df_earn = df_earn[df_earn.index < '2024-09-30']

    # Merge dataframes
    df = pd.concat([df_bs, df_is, df_cf, df_earn], axis=1)
    df = df.apply(pd.to_numeric, errors='coerce').fillna(0).astype(float)

    # Filter for dates after 2019-09-31
    df = df[df.index > '2019-09-31']

    # Calculate financial ratios
    df['current_ratio'] = df['totalCurrentAssets'] / df['totalCurrentLiabilities']
    df['quick_ratio'] = (df['totalCurrentAssets'] - df['inventory']) / df['totalCurrentLiabilities']
    df['debt_to_equity'] = df['totalLiab'] / df['totalStockholderEquity']
    df['interest_coverage_ratio'] = df['ebit'] / df['interestExpense']
    df['gross_profit_margin'] = (df['totalRevenue'] - df['costOfRevenue']) / df['totalRevenue']
    df['operating_income_margin'] = df['operatingIncome'] / df['totalRevenue']
    df['net_profit_margin'] = df['netIncome'] / df['totalRevenue']
    df['ROA'] = df['netIncome'] / df['totalAssets']
    df['ROE'] = df['netIncome'] / df['totalStockholderEquity']
    df['asset_turnover_ratio'] = df['totalRevenue'] / df['totalAssets']
    df['operating_cash_flow_to_total_debt'] = df['totalCashFromOperatingActivities'] / df['netDebt']

    # Get stock prices
    price_df = get_stock_prices(ticker, api_token)

    # Create a buffer dataframe to fill close price from the previous date on the report date
    df_buffer = pd.concat([df, price_df], axis=1).sort_index().ffill()

    # Merge dataset with close price and other indicators. Sort indexes to calculate the right return
    df = pd.merge(left=df, right=df_buffer['close'], how='left', left_index=True, right_index=True)
    df = df.sort_index()

    # Add PE ratio
    df['PE'] = df['close'] / df['epsActual']

    # Calculate growth rates
    df['revenue_growth'] = df['totalRevenue'].pct_change()
    df['earnings_growth'] = df['netIncome'].pct_change()
    df['return'] = df['close'].pct_change()

    # Keep only necessary columns
    df = df[['freeCashFlow', 'current_ratio', 'quick_ratio', 'debt_to_equity',
       'interest_coverage_ratio', 'gross_profit_margin',
       'operating_income_margin', 'net_profit_margin', 'ROA', 'ROE',
       'asset_turnover_ratio', 'operating_cash_flow_to_total_debt', 'close',
       'PE', 'revenue_growth', 'earnings_growth', 'return']]

    df = df[df.index > '2019-12-31']

    return df

# %%
# Function to process multiple tickers and save the result to CSV
# Batch processing with pause (e.g., every 50 tickers)
def process_and_save_tickers_to_zip_in_batches(ticker_list, api_token, zip_filename='financial_data.zip', batch_size=50, delay=60):
    # Create a new in-memory zip archive
    with zipfile.ZipFile(zip_filename, 'w', zipfile.ZIP_DEFLATED) as zipf:
        for i in range(0, len(ticker_list), batch_size):
            batch = ticker_list[i:i+batch_size]
            for ticker in batch:
                try:
                    # Process the financial data for each ticker
                    df_final = process_financial_data(ticker, api_token)

                    # Convert the DataFrame to CSV in-memory
                    csv_buffer = io.StringIO()
                    df_final.to_csv(csv_buffer)

                    # Write CSV data to the ZIP archive
                    zipf.writestr(f"{ticker}_final.csv", csv_buffer.getvalue())

                    print(f"Processed and added {ticker} to {zip_filename}")
                except Exception as e:
                    print(f"Error processing {ticker}: {e}")

            # Optional delay after processing each batch to avoid hitting API limits
            print(f"Batch {i//batch_size + 1} completed. Pausing for {delay} seconds.")
            time.sleep(delay)

# %%
api_token =  '6710b76ee76761.47900881'

# %%
process_and_save_tickers_to_zip_in_batches(symbol_list, api_token)
# Out:
# Processed and added MMM to financial_data.zip
# Processed and added AOS to financial_data.zip
# Processed and added ABT to financial_data.zip
# Processed and added ABBV to financial_data.zip
# Processed and added ACN to financial_data.zip
# Processed and added ADBE to financial_data.zip
# Processed and added AMD to financial_data.zip
# Processed and added AES to financial_data.zip
# Processed and added AFL to financial_data.zip
# Processed and added A to financial_data.zip
# Processed and added APD to financial_data.zip
# Processed and added AKAM to financial_data.zip
# Processed and added ALB to financial_data.zip
# Processed and added ARE to financial_data.zip
# Processed and added ALGN to financial_data.zip
# Processed and added ALLE to financial_data.zip
# Processed and added LNT to financial_data.zip
# Processed and added ALL to financial_data.zip
# Processed and added GOOGL to financial_data.zip
# Processed and added GOOG to financial_data.zip
# Processed and added MO to financial_data.zip
# Processed and added AMZN to financial_data.zip
# Processed and added AEE to financial_data.zip
# Processed and added AEP to financial_data.zip
# Processed and added AXP to financial_data.zip
# Processed and added AIG to financial_data.zip
# Processed and added AMT to financial_data.zip
# Processed and added AWK to financial_data.zip
# Processed and added AMP to financial_data.zip
# Processed and added AME to financial_data.zip
# Processed and added AMGN to financial_data.zip
# Processed and added APH to financial_data.zip
# Processed and added ADI to financial_data.zip
# Processed and added ANSS to financial_data.zip
# Processed and added AON to financial_data.zip
# Processed and added APA to financial_data.zip
# Processed and added AAPL to financial_data.zip
# Processed and added AMAT to financial_data.zip
# Processed and added APTV to financial_data.zip
# Processed and added ADM to financial_data.zip
# Processed and added ANET to financial_data.zip
# Processed and added AJG to financial_data.zip
# Processed and added AIZ to financial_data.zip
# Processed and added T to financial_data.zip
# Processed and added ADSK to financial_data.zip
# Processed and added ADP to financial_data.zip
# Processed and added AZO to financial_data.zip
# Processed and added AVB to financial_data.zip
# Processed and added AVY to financial_data.zip
# Processed and added BKR to financial_data.zip
# Batch 1 completed. Pausing for 60 seconds.
# Processed and added BALL to financial_data.zip
# Processed and added BAC to financial_data.zip
# Processed and added BAX to financial_data.zip
# Processed and added BDX to financial_data.zip
# Error processing BRK.B: Expecting value: line 1 column 1 (char 0)
# Processed and added BBY to financial_data.zip
# Processed and added BIIB to financial_data.zip
# Processed and added BLK to financial_data.zip
# Processed and added BK to financial_data.zip
# Processed and added BA to financial_data.zip
# Processed and added BKNG to financial_data.zip
# Processed and added BWA to financial_data.zip
# Processed and added BSX to financial_data.zip
# Processed and added BMY to financial_data.zip
# Processed and added AVGO to financial_data.zip
# Processed and added BR to financial_data.zip
# Error processing BF.B: Expecting value: line 1 column 1 (char 0)
# Processed and added BXP to financial_data.zip
# Processed and added CHRW to financial_data.zip
# Processed and added CDNS to financial_data.zip
# Processed and added CPB to financial_data.zip
# Processed and added COF to financial_data.zip
# Processed and added CAH to financial_data.zip
# Processed and added KMX to financial_data.zip
# Processed and added CCL to financial_data.zip
# Processed and added CAT to financial_data.zip
# Processed and added CBOE to financial_data.zip
# Processed and added CBRE to financial_data.zip
# Processed and added CE to financial_data.zip
# Processed and added COR to financial_data.zip
# Processed and added CNC to financial_data.zip
# Processed and added CNP to financial_data.zip
# Processed and added CF to financial_data.zip
# Processed and added SCHW to financial_data.zip
# Processed and added CHTR to financial_data.zip
# Processed and added CVX to financial_data.zip
# Processed and added CMG to financial_data.zip
# Processed and added CB to financial_data.zip
# Processed and added CHD to financial_data.zip
# Processed and added CI to financial_data.zip
# Processed and added CINF to financial_data.zip
# Processed and added CTAS to financial_data.zip
# Processed and added CSCO to financial_data.zip
# Processed and added C to financial_data.zip
# Processed and added CFG to financial_data.zip
# Processed and added CLX to financial_data.zip
# Processed and added CME to financial_data.zip
# Processed and added CMS to financial_data.zip
# Processed and added KO to financial_data.zip
# Processed and added CTSH to financial_data.zip
# Batch 2 completed. Pausing for 60 seconds.
# Processed and added CL to financial_data.zip
# Processed and added CMCSA to financial_data.zip
# Processed and added CAG to financial_data.zip
# Processed and added COP to financial_data.zip
# Processed and added ED to financial_data.zip
# Processed and added STZ to financial_data.zip
# Processed and added COO to financial_data.zip
# Processed and added CPRT to financial_data.zip
# Processed and added GLW to financial_data.zip
# Processed and added CPAY to financial_data.zip
# Processed and added COST to financial_data.zip
# Processed and added CTRA to financial_data.zip
# Processed and added CCI to financial_data.zip
# Processed and added CSX to financial_data.zip
# Processed and added CMI to financial_data.zip
# Processed and added CVS to financial_data.zip
# Processed and added DHR to financial_data.zip
# Processed and added DRI to financial_data.zip
# Processed and added DVA to financial_data.zip
# Processed and added DE to financial_data.zip
# Processed and added DAL to financial_data.zip
# Processed and added DVN to financial_data.zip
# Processed and added FANG to financial_data.zip
# Processed and added DLR to financial_data.zip
# Processed and added DFS to financial_data.zip
# Processed and added DG to financial_data.zip
# Processed and added DLTR to financial_data.zip
# Processed and added D to financial_data.zip
# Processed and added DOV to financial_data.zip
# Processed and added DHI to financial_data.zip
# Processed and added DTE to financial_data.zip
# Processed and added DUK to financial_data.zip
# Processed and added EMN to financial_data.zip
# Processed and added ETN to financial_data.zip
# Processed and added EBAY to financial_data.zip
# Processed and added ECL to financial_data.zip
# Processed and added EIX to financial_data.zip
# Processed and added EW to financial_data.zip
# Processed and added EA to financial_data.zip
# Processed and added ELV to financial_data.zip
# Processed and added EMR to financial_data.zip
# Processed and added ETR to financial_data.zip
# Processed and added EOG to financial_data.zip
# Processed and added EFX to financial_data.zip
# Processed and added EQIX to financial_data.zip
# Processed and added EQR to financial_data.zip
# Processed and added ESS to financial_data.zip
# Processed and added EL to financial_data.zip
# Processed and added EG to financial_data.zip
# Processed and added EVRG to financial_data.zip
# Batch 3 completed. Pausing for 60 seconds.
# Processed and added ES to financial_data.zip
# Processed and added EXC to financial_data.zip
# Processed and added EXPE to financial_data.zip
# Processed and added EXPD to financial_data.zip
# Processed and added EXR to financial_data.zip
# Processed and added XOM to financial_data.zip
# Processed and added FFIV to financial_data.zip
# Processed and added FAST to financial_data.zip
# Processed and added FRT to financial_data.zip
# Processed and added FDX to financial_data.zip
# Processed and added FIS to financial_data.zip
# Processed and added FITB to financial_data.zip
# Processed and added FE to financial_data.zip
# Processed and added FI to financial_data.zip
# Processed and added FMC to financial_data.zip
# Processed and added F to financial_data.zip
# Processed and added FTNT to financial_data.zip
# Processed and added FTV to financial_data.zip
# Processed and added BEN to financial_data.zip
# Processed and added FCX to financial_data.zip
# Processed and added GRMN to financial_data.zip
# Processed and added IT to financial_data.zip
# Processed and added GE to financial_data.zip
# Processed and added GEN to financial_data.zip
# Processed and added GD to financial_data.zip
# Processed and added GIS to financial_data.zip
# Processed and added GM to financial_data.zip
# Processed and added GPC to financial_data.zip
# Processed and added GILD to financial_data.zip
# Processed and added GPN to financial_data.zip
# Processed and added GL to financial_data.zip
# Processed and added GS to financial_data.zip
# Processed and added HAL to financial_data.zip
# Processed and added HIG to financial_data.zip
# Processed and added HAS to financial_data.zip
# Processed and added HCA to financial_data.zip
# Processed and added DOC to financial_data.zip
# Processed and added HSIC to financial_data.zip
# Processed and added HSY to financial_data.zip
# Processed and added HES to financial_data.zip
# Processed and added HPE to financial_data.zip
# Processed and added HLT to financial_data.zip
# Processed and added HOLX to financial_data.zip
# Processed and added HD to financial_data.zip
# Processed and added HON to financial_data.zip
# Processed and added HRL to financial_data.zip
# Processed and added HST to financial_data.zip
# Processed and added HWM to financial_data.zip
# Processed and added HPQ to financial_data.zip
# Processed and added HUM to financial_data.zip
# Batch 4 completed. Pausing for 60 seconds.
# Processed and added HBAN to financial_data.zip
# Processed and added HII to financial_data.zip
# Processed and added IBM to financial_data.zip
# Processed and added IDXX to financial_data.zip
# Processed and added ITW to financial_data.zip
# Processed and added INCY to financial_data.zip
# Processed and added INTC to financial_data.zip
# Processed and added ICE to financial_data.zip
# Processed and added IFF to financial_data.zip
# Processed and added IP to financial_data.zip
# Processed and added IPG to financial_data.zip
# Processed and added INTU to financial_data.zip
# Processed and added ISRG to financial_data.zip
# Processed and added IVZ to financial_data.zip
# Processed and added IQV to financial_data.zip
# Processed and added IRM to financial_data.zip
# Processed and added JBHT to financial_data.zip
# Processed and added JKHY to financial_data.zip
# Processed and added J to financial_data.zip
# Processed and added JNJ to financial_data.zip
# Processed and added JCI to financial_data.zip
# Processed and added JPM to financial_data.zip
# Processed and added JNPR to financial_data.zip
# Processed and added K to financial_data.zip
# Processed and added KEY to financial_data.zip
# Processed and added KEYS to financial_data.zip
# Processed and added KMB to financial_data.zip
# Processed and added KIM to financial_data.zip
# Processed and added KMI to financial_data.zip
# Processed and added KLAC to financial_data.zip
# Processed and added KHC to financial_data.zip
# Processed and added KR to financial_data.zip
# Processed and added LHX to financial_data.zip
# Processed and added LH to financial_data.zip
# Processed and added LRCX to financial_data.zip
# Processed and added LW to financial_data.zip
# Processed and added LEN to financial_data.zip
# Processed and added LLY to financial_data.zip
# Processed and added LIN to financial_data.zip
# Processed and added LKQ to financial_data.zip
# Processed and added LMT to financial_data.zip
# Processed and added L to financial_data.zip
# Processed and added LOW to financial_data.zip
# Processed and added LYB to financial_data.zip
# Processed and added MTB to financial_data.zip
# Processed and added MRO to financial_data.zip
# Processed and added MPC to financial_data.zip
# Processed and added MAR to financial_data.zip
# Processed and added MMC to financial_data.zip
# Processed and added MLM to financial_data.zip
# Batch 5 completed. Pausing for 60 seconds.
# Processed and added MAS to financial_data.zip
# Processed and added MA to financial_data.zip
# Processed and added MKC to financial_data.zip
# Processed and added MCD to financial_data.zip
# Processed and added MCK to financial_data.zip
# Processed and added MDT to financial_data.zip
# Processed and added MRK to financial_data.zip
# Processed and added META to financial_data.zip
# Processed and added MET to financial_data.zip
# Processed and added MTD to financial_data.zip
# Processed and added MGM to financial_data.zip
# Processed and added MCHP to financial_data.zip
# Processed and added MU to financial_data.zip
# Processed and added MSFT to financial_data.zip
# Processed and added MAA to financial_data.zip
# Processed and added MHK to financial_data.zip
# Processed and added TAP to financial_data.zip
# Processed and added MDLZ to financial_data.zip
# Processed and added MNST to financial_data.zip
# Processed and added MCO to financial_data.zip
# Processed and added MS to financial_data.zip
# Processed and added MOS to financial_data.zip
# Processed and added MSI to financial_data.zip
# Processed and added MSCI to financial_data.zip
# Processed and added NDAQ to financial_data.zip
# Processed and added NTAP to financial_data.zip
# Processed and added NFLX to financial_data.zip
# Processed and added NEM to financial_data.zip
# Processed and added NWSA to financial_data.zip
# Processed and added NWS to financial_data.zip
# Processed and added NEE to financial_data.zip
# Processed and added NKE to financial_data.zip
# Processed and added NI to financial_data.zip
# Processed and added NSC to financial_data.zip
# Processed and added NTRS to financial_data.zip
# Processed and added NOC to financial_data.zip
# Processed and added NCLH to financial_data.zip
# Processed and added NRG to financial_data.zip
# Processed and added NUE to financial_data.zip
# Processed and added NVDA to financial_data.zip
# Processed and added ORLY to financial_data.zip
# Processed and added OXY to financial_data.zip
# Processed and added OMC to financial_data.zip
# Processed and added OKE to financial_data.zip
# Processed and added ORCL to financial_data.zip
# Processed and added PCAR to financial_data.zip
# Processed and added PKG to financial_data.zip
# Processed and added PARA to financial_data.zip
# Processed and added PH to financial_data.zip
# Processed and added PAYX to financial_data.zip
# Batch 6 completed. Pausing for 60 seconds.
# Processed and added PYPL to financial_data.zip
# Processed and added PNR to financial_data.zip
# Processed and added PEP to financial_data.zip
# Processed and added PFE to financial_data.zip
# Processed and added PM to financial_data.zip
# Processed and added PSX to financial_data.zip
# Processed and added PNW to financial_data.zip
# Processed and added PNC to financial_data.zip
# Processed and added PPG to financial_data.zip
# Processed and added PPL to financial_data.zip
# Processed and added PFG to financial_data.zip
# Processed and added PG to financial_data.zip
# Processed and added PGR to financial_data.zip
# Processed and added PLD to financial_data.zip
# Processed and added PRU to financial_data.zip
# Processed and added PEG to financial_data.zip
# Processed and added PSA to financial_data.zip
# Processed and added PHM to financial_data.zip
# Processed and added QRVO to financial_data.zip
# Processed and added PWR to financial_data.zip
# Processed and added QCOM to financial_data.zip
# Processed and added DGX to financial_data.zip
# Processed and added RL to financial_data.zip
# Processed and added RJF to financial_data.zip
# Processed and added RTX to financial_data.zip
# Processed and added O to financial_data.zip
# Processed and added REG to financial_data.zip
# Processed and added REGN to financial_data.zip
# Processed and added RF to financial_data.zip
# Processed and added RSG to financial_data.zip
# Processed and added RMD to financial_data.zip
# Processed and added RVTY to financial_data.zip
# Processed and added ROK to financial_data.zip
# Processed and added ROL to financial_data.zip
# Processed and added ROP to financial_data.zip
# Processed and added ROST to financial_data.zip
# Processed and added RCL to financial_data.zip
# Processed and added SPGI to financial_data.zip
# Processed and added CRM to financial_data.zip
# Processed and added SBAC to financial_data.zip
# Processed and added SLB to financial_data.zip
# Processed and added STX to financial_data.zip
# Processed and added SRE to financial_data.zip
# Processed and added SHW to financial_data.zip
# Processed and added SPG to financial_data.zip
# Processed and added SWKS to financial_data.zip
# Processed and added SJM to financial_data.zip
# Processed and added SNA to financial_data.zip
# Processed and added SO to financial_data.zip
# Processed and added LUV to financial_data.zip
# Batch 7 completed. Pausing for 60 seconds.
# Processed and added SWK to financial_data.zip
# Processed and added SBUX to financial_data.zip
# Processed and added STT to financial_data.zip
# Processed and added SYK to financial_data.zip
# Processed and added SYF to financial_data.zip
# Processed and added SNPS to financial_data.zip
# Processed and added SYY to financial_data.zip
# Processed and added TTWO to financial_data.zip
# Processed and added TPR to financial_data.zip
# Processed and added TGT to financial_data.zip
# Processed and added TEL to financial_data.zip
# Processed and added TXN to financial_data.zip
# Processed and added TXT to financial_data.zip
# Processed and added TMO to financial_data.zip
# Processed and added TJX to financial_data.zip
# Processed and added TSCO to financial_data.zip
# Processed and added TT to financial_data.zip
# Processed and added TDG to financial_data.zip
# Processed and added TRV to financial_data.zip
# Processed and added TFC to financial_data.zip
# Processed and added TSN to financial_data.zip
# Processed and added USB to financial_data.zip
# Processed and added UDR to financial_data.zip
# Processed and added ULTA to financial_data.zip
# Processed and added UNP to financial_data.zip
# Processed and added UAL to financial_data.zip
# Processed and added UPS to financial_data.zip
# Processed and added URI to financial_data.zip
# Processed and added UNH to financial_data.zip
# Processed and added UHS to financial_data.zip
# Processed and added VLO to financial_data.zip
# Processed and added VTR to financial_data.zip
# Processed and added VRSN to financial_data.zip
# Processed and added VRSK to financial_data.zip
# Processed and added VZ to financial_data.zip
# Processed and added VRTX to financial_data.zip
# Processed and added VTRS to financial_data.zip
# Processed and added V to financial_data.zip
# Processed and added VMC to financial_data.zip
# Processed and added GWW to financial_data.zip
# Processed and added WBA to financial_data.zip
# Processed and added WMT to financial_data.zip
# Processed and added DIS to financial_data.zip
# Processed and added WM to financial_data.zip
# Processed and added WAT to financial_data.zip
# Processed and added WEC to financial_data.zip
# Processed and added WFC to financial_data.zip
# Processed and added WELL to financial_data.zip
# Processed and added WDC to financial_data.zip
# Processed and added WY to financial_data.zip
# Batch 8 completed. Pausing for 60 seconds.
# Processed and added WMB to financial_data.zip
# Processed and added WTW to financial_data.zip
# Processed and added WYNN to financial_data.zip
# Processed and added XEL to financial_data.zip
# Processed and added XYL to financial_data.zip
# Processed and added YUM to financial_data.zip
# Processed and added ZBH to financial_data.zip
# Processed and added ZTS to financial_data.zip
# Batch 9 completed. Pausing for 60 seconds.

# %%
def process_and_save_tickers(ticker_list, api_token):
    for ticker in ticker_list:
            df_final = process_financial_data(ticker, api_token)
            # Save to CSV
            df_final.to_csv(f"{ticker}_final.csv")
            print(f"Processed and saved {ticker}")

# %%
ticker_list = ['TSLA']
process_and_save_tickers(ticker_list, api_token)
# Out:
# Processed and saved TSLA
